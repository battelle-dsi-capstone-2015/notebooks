# %% [markdown]
# # Topics by Max Word Weights

# %% [markdown]
# This notebook explores the distribution of word frequencies in a corpus. It shows what one might expect --

# %%
# %matplotlib inline

# %%
import sqlite3, matplotlib
import pandas as pd
import matplotlib.pyplot as plt

matplotlib.style.use('ggplot')

z = 40
iterations = 500
data = []
dbfile = ''
dbfile = '/Users/rca2t/Documents/Projects/polo_test/projects/demo/trials/default/demo-default-z{0}-i{1}.db'.format(z,iterations)
with sqlite3.connect(dbfile) as conn:
    cur = conn.cursor()    
    for i in range(int(z)):
        sql = "SELECT word_str, max(t{0}), {0} as 'topic' FROM wordtopic".format(i)
        for r in cur.execute(sql):
            data.append(r)
            
data = sorted(data, key=lambda tup: tup[1])
df = pd.DataFrame(data, columns=['word','weight','topic']) #.sort_values('weight')
fig, ax = plt.subplots(figsize=(15,15))
ax.scatter(df['topic'],df['weight'])
ax.plot(df['weight'])

for d in data:
    if d[1] < 75: continue
    label = 't{1} {0}'.format(d[0],d[2])
    x = d[2] 
    y = d[1]
    ax.annotate(label,xy=(x,y),xytext=(-10,10),textcoords='offset pixels')

# %%
df.sort_values(['weight'], ascending=0).head(100)
# Out:
#              word      weight
# 59           case  495.016316
# 58          molly  268.016316
# 57           case  261.016316
# 56       armitage  118.016316
# 55           eyes  100.016316
# 54           finn   95.016316
# 53        riviera   80.016316
# 52     wintermute   73.016316
# 51          place   61.016316
# 50      construct   60.016316
# 49           jane   60.016316
# 48           eyes   58.016316
# 47        maelcum   56.016316
# 46          deane   54.016316
# 45     straylight   52.016316
# 44           door   50.016316
# 43        maelcum   48.016316
# 42           room   47.016316
# 41           dead   46.016316
# 40           ratz   45.016316
# 39          table   40.016316
# 38        beneath   39.016316
# 37          corto   38.016316
# 36            net   35.016316
# 35           blue   35.016316
# 34           wall   33.016316
# 33          black   31.016316
# 32          small   28.016316
# 31          smith   26.016316
# 30            gun   26.016316
# 29            leg   25.016316
# 28           chip   25.016316
# 27         passed   25.016316
# 26         jacked   24.016316
# 25            key   23.016316
# 24          hotel   22.016316
# 23          beach   21.016316
# 22            sky   21.016316
# 21          gonna   19.016316
# 20         worked   19.016316
# 19          braun   19.016316
# 18     cyberspace   19.016316
# 17          music   19.016316
# 16        watched   18.016316
# 14       shuriken   17.016316
# 15         arcade   17.016316
# 13         pierre   16.016316
# 12        silence   15.016316
# 11          bruce   14.016316
# 10           data   14.016316
# 9              ai   14.016316
# 2             war   12.016316
# 8           voice   12.016316
# 7            nest   12.016316
# 6      understand   12.016316
# 5   terzibashjian   12.016316
# 4            dome   12.016316
# 3            hour   12.016316
# 1         blurred    9.016316
# 0            shop    9.016316
